# %% [markdown]
# <a href="https://colab.research.google.com/github/karenswang/computational-journalism/blob/main/Computational_Journalism_Meeting_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Programming up some scraping**
#
# Here we program up some of the ideas in the accompanying slide deck. First, we look at [kick.com](kick.com). Try to bring into Python information about the the trending feeds at the moment. In the "code cell" below, we have my attempt from this morning. You should only peek if you have to.

# %%
# @title
s = """{"current_page":4,"data":[{"id":23779615,"slug":"81475268-deepak-x-hyub-last-day-in-jaisalmer","channel_id":4431300,"created_at":"2024-02-22 04:25:08","session_title":"Deepak x Jay !tts !media !discord","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 04:25:05","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":false,"viewer_count":914,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/MCrHDtiN4Bof\/kL5U0P7DON1m\/720.webp"},"viewers":914,"channel":{"id":4431300,"user_id":4515227,"slug":"deepak","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.MCrHDtiN4Bof.m3u8","name_updated_at":null,"vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":4515227,"username":"Deepak","agreed_to_terms":true,"email_verified_at":"2023-05-12T16:22:54.000000Z","bio":"","country":"","state":"","city":"","instagram":"Deepak live on kick","twitter":"DeepakLal914434","youtube":"@deepaklal6660","discord":"F4t32nz2Xd","tiktok":"","facebook":"","profilepic":"https:\/\/files.kick.com\/images\/user\/4515227\/profile_image\/conversion\/cf5ae014-8ce7-4856-aae0-2bc6caf17618-thumb.webp"}},"categories":[{"id":15,"category_id":2,"name":"Just Chatting","slug":"just-chatting","tags":["IRL"],"description":null,"deleted_at":null,"viewers":24713,"category":{"id":2,"name":"IRL","slug":"irl","icon":"\ud83c\udf99\ufe0f"}}]},{"id":23788926,"slug":"62636979-300-to-3k-pls-max-win-stake","channel_id":102267,"created_at":"2024-02-22 12:07:37","session_title":"$300 to 3k pls max win !Stake","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 12:07:37","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":853,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/V6isCH3R795j\/lPGvOC35KnR0\/720.webp"},"viewers":853,"channel":{"id":102267,"user_id":103430,"slug":"zirinic","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.V6isCH3R795j.m3u8","name_updated_at":"2023-02-26 11:53:00","vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":103430,"username":"Zirinic","agreed_to_terms":true,"email_verified_at":"2022-12-08T10:17:08.000000Z","bio":"STAKE BJ IS MY DADA","country":"","state":"","city":"","instagram":"","twitter":"Zirinic","youtube":"Zirinic","discord":"sw5fA6y2","tiktok":"Zirinicc","facebook":"","profilepic":"https:\/\/files.kick.com\/images\/user\/103430\/profile_image\/conversion\/12923df2-3f3f-4937-9842-2251f40294a9-thumb.webp"}},"categories":[{"id":28,"category_id":4,"name":"Slots & Casino","slug":"slots","tags":["Gambling"],"description":null,"deleted_at":null,"viewers":12084,"category":{"id":4,"name":"Gambling","slug":"gambling","icon":"\ud83c\udfb0"}}]},{"id":23787793,"slug":"66364-5000-viewer-hunt-type-stake-for-free-25","channel_id":51042,"created_at":"2024-02-22 10:50:42","session_title":"$5,000 VIEWER HUNT | Type !stake for FREE $25","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 10:50:41","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":350,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/wAjXTVMmMOa2\/L3Fcsuy2rGZ2\/720.webp"},"viewers":350,"channel":{"id":51042,"user_id":51457,"slug":"averageaden","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.wAjXTVMmMOa2.m3u8","name_updated_at":null,"vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":51457,"username":"AverageAden","agreed_to_terms":true,"email_verified_at":"2022-12-05T10:57:23.000000Z","bio":"Streaming since 2018. Co-founder of Onlyfans. Cant stick to a schedule. Twitter- @AverageAden Youtube- AverageAden","country":"","state":"","city":"","instagram":"","twitter":"averageaden","youtube":"@averageaden","discord":"","tiktok":"","facebook":"","profilepic":"https:\/\/files.kick.com\/images\/user\/51457\/profile_image\/conversion\/25aa8dd4-9ff0-4451-8a66-66ab423a536a-thumb.webp"}},"categories":[{"id":28,"category_id":4,"name":"Slots & Casino","slug":"slots","tags":["Gambling"],"description":null,"deleted_at":null,"viewers":12084,"category":{"id":4,"name":"Gambling","slug":"gambling","icon":"\ud83c\udfb0"}}]},{"id":23751562,"slug":"5a186-win-wine-wednesday-wblonderabbit-gfuel-socials","channel_id":1238544,"created_at":"2024-02-21 19:01:14","session_title":"Win & Wine Wednesday W\/Blonderabbit !gfuel !socials","is_live":true,"risk_level_id":null,"start_time":"2024-02-21 19:01:12","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":185,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/FumClcMbnw7T\/zgjx4YzEirnE\/720.webp"},"viewers":185,"channel":{"id":1238544,"user_id":1280763,"slug":"mz_konflikted","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.FumClcMbnw7T.m3u8","name_updated_at":"2023-03-09 02:02:55","vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":1280763,"username":"Mz_KoNFliKTeD","agreed_to_terms":true,"email_verified_at":"2023-02-25T20:14:32.000000Z","bio":"Hey there! I'm a really quirky person who loves playing video games to escape from real life. I enjoy meeting new people and making friends. Whenever I go live, I play games with my viewers, except on Fridays when I hang out and have fun with my friends while having a few drinks.\n\nI'm known for being funny, ambitious, and caring. I don't hold back and speak my mind without any filters. I'm all about making people laugh and bringing joy to their day.","country":"","state":"","city":"","instagram":"mz_konflikted","twitter":"MKonflikted","youtube":"@MzKoNFliKTed","discord":"https:\/\/discord.gg\/NsuVBscukK","tiktok":"mz_konflikted","facebook":"profile.php?id=100089488699297","profilepic":"https:\/\/files.kick.com\/images\/user\/1280763\/profile_image\/conversion\/c4a4d475-b04f-46ec-acc1-a95fbaa44e06-thumb.webp"}},"categories":[{"id":28,"category_id":4,"name":"Slots & Casino","slug":"slots","tags":["Gambling"],"description":null,"deleted_at":null,"viewers":12084,"category":{"id":4,"name":"Gambling","slug":"gambling","icon":"\ud83c\udfb0"}}]},{"id":23720851,"slug":"acfc6-helldivers-2-then-the-wz-grind-continues-veteran-regiment-f3-merch","channel_id":1622911,"created_at":"2024-02-21 01:51:04","session_title":"Helldivers 2 then.... The WZ grind continues! | VETERAN | Regiment | !f3 !merch","is_live":true,"risk_level_id":null,"start_time":"2024-02-21 01:51:03","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":158,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/rshaXZt6UaE3\/nHgIPw3GWvGI\/720.webp"},"viewers":158,"channel":{"id":1622911,"user_id":1671531,"slug":"littlenicky19","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.rshaXZt6UaE3.m3u8","name_updated_at":null,"vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":1671531,"username":"Littlenicky19","agreed_to_terms":true,"email_verified_at":"2023-03-11T22:10:30.000000Z","bio":"Disabled USAF Veteran. Member of REGIMENT! Served 5 1\/2 years. 3 deployments. Ready for the next chapter. For business inquiries please email thelittlenicky19@gmail.com","country":"","state":"","city":"","instagram":"https:\/\/www.instagram.com\/little_nicky19\/","twitter":"https:\/\/twitter.com\/Little_Nicky19","youtube":"https:\/\/www.youtube.com\/@LittleNicky19","discord":"https:\/\/discord.com\/invite\/mg7uS57dzg","tiktok":"http:\/\/www.tiktok.com\/@littlenicky19_","facebook":"https:\/\/www.facebook.com\/people\/LittleNicky19\/100089480916714\/?mibextid=LQQJ4d","profilepic":"https:\/\/files.kick.com\/images\/user\/1671531\/profile_image\/conversion\/a6148c8e-477b-46d0-a453-ce6696f85a3a-thumb.webp"}},"categories":[{"id":4804,"category_id":1,"name":"Helldivers II","slug":"helldivers-ii","tags":["Shooter","Strategy"],"description":null,"deleted_at":null,"viewers":296,"category":{"id":1,"name":"Games","slug":"games","icon":"\ud83d\udd79\ufe0f"}}]},{"id":23787661,"slug":"09181440-late-slotmagusta-is-here-sarodiscord-stake-for-our-200-welcome-offer-giveaway-for-our-5000-monthly-giveaway","channel_id":5021,"created_at":"2024-02-22 10:41:23","session_title":"Late slotmagusta is here | Saro!discord !Stake For Our 200% Welcome Offer | !Giveaway For Our $5.000 Monthly Giveaway","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 10:41:21","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":114,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/SiSY2oeAgASb\/cBjyWrZWcqAu\/720.webp"},"viewers":114,"channel":{"id":5021,"user_id":5070,"slug":"cheekygamblers","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.SiSY2oeAgASb.m3u8","name_updated_at":"2023-01-17 21:56:29","vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":5070,"username":"CheekyGamblers","agreed_to_terms":true,"email_verified_at":"2022-11-22T19:39:25.000000Z","bio":"Welcome to Cheeky Gamblers, the home of high-quality slots streams, the best online casino reviews, and the greatest gambling community on the web. Follow Slotmamba, Saro and Tsaf Tsouf on an epic journey around the best casinos, with five live streams every week. Do you think you\u2019re brave enough to follow his loud and high-energy pace? If the answer is yes, then you\u2019re in the right place!","country":null,"state":null,"city":null,"instagram":"cheekyGamblers","twitter":"CheekyGamblers","youtube":"@cheekygamblers","discord":"Nsdr98kHJN","tiktok":"cheekygamblers","facebook":"profile.php?id=100083319011715","profilepic":"https:\/\/files.kick.com\/images\/user\/5070\/profile_image\/conversion\/4b3767cf-8595-4631-8dc5-cc2387a0bef8-thumb.webp"}},"categories":[{"id":28,"category_id":4,"name":"Slots & Casino","slug":"slots","tags":["Gambling"],"description":null,"deleted_at":null,"viewers":12084,"category":{"id":4,"name":"Gambling","slug":"gambling","icon":"\ud83c\udfb0"}}]},{"id":23756705,"slug":"24466053-giveaway-partner-grind-tam-mcgaw-noego-rp","channel_id":1517751,"created_at":"2024-02-21 20:53:46","session_title":"!giveaway Partner Grind Tam McGaw - NoEgo RP","is_live":true,"risk_level_id":null,"start_time":"2024-02-21 20:53:42","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":110,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/CG7Zu5THm9lM\/sQkwbmT97sid\/720.webp"},"viewers":110,"channel":{"id":1517751,"user_id":1564652,"slug":"big_mikey","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.CG7Zu5THm9lM.m3u8","name_updated_at":"2023-12-07 18:56:08","vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":1564652,"username":"Big_Mikey","agreed_to_terms":true,"email_verified_at":"2023-03-06T20:14:38.000000Z","bio":"Formerly known as Th33_j0k3r_10, I'm 31 years old, Scottish Streamer. Started off on Facebook where I got to just over 4k followers. then about 2 months on twitch where I got to over 1k followers. I then decided to dive into Kick. I am a multi game playing Streamer, however majority of the time I will be streaming GTA RP on NoPixel RP WL. I have an amazing Community and we tend to have a lot of Fun in Chat...\n\nBusiness Enquiries Email - mikey1992@hotmail.com","country":"","state":"","city":"","instagram":"","twitter":"https:\/\/twitter.com\/Big_MikeyGames","youtube":"","discord":"Q8hFN2teP6","tiktok":"https:\/\/www.tiktok.com\/@big_mikeygames","facebook":"","profilepic":"https:\/\/files.kick.com\/images\/user\/1564652\/profile_image\/conversion\/97b5cf42-298c-42f0-a84e-80103ee8aebb-thumb.webp"}},"categories":[{"id":8,"category_id":1,"name":"Grand Theft Auto V (GTA)","slug":"grand-theft-auto-v","tags":["Shooter","Action","Open World"],"description":"Grand Theft Auto V is a vast open world game set in Los Santos, a sprawling sun-soaked metropolis struggling to stay afloat in an era of economic uncertainty and cheap reality TV. The game blends storytelling and gameplay in new ways as players repeatedly jump in and out of the lives of the game\u2019s three lead characters, playing all sides of the game\u2019s interwoven story.","deleted_at":null,"viewers":800,"category":{"id":1,"name":"Games","slug":"games","icon":"\ud83d\udd79\ufe0f"}}]},{"id":23787282,"slug":"10341014-live-streamers-be-carefull-the-booby-trapper-is-here","channel_id":32815,"created_at":"2024-02-22 10:12:56","session_title":"\ud83d\udd34 | LIVE | Streamers Be Carefull The Booby Trapper Is Here","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 10:12:51","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":true,"viewer_count":108,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/frodaXwWSMna\/ylIbT0zoHSqC\/720.webp"},"viewers":108,"channel":{"id":32815,"user_id":33065,"slug":"johnessy","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.frodaXwWSMna.m3u8","name_updated_at":null,"vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":33065,"username":"johnessy","agreed_to_terms":true,"email_verified_at":"2022-11-28T15:46:15.000000Z","bio":"Sup, Im John, I feel like im writing some sort of job application here. Sooo yeah, Im John :D 148K On Facebook, Previous partner, got terminated because i chose to stream here :D Now Get In Chat!. Business Enquiries - jake.cass@aegis.tm","country":"","state":"","city":"","instagram":"johnessy1689","twitter":"RealJohnessy","youtube":"@Johnessy","discord":"johnessy","tiktok":"itsjohnessy","facebook":"itsjohnessy","profilepic":"https:\/\/files.kick.com\/images\/user\/33065\/profile_image\/conversion\/94737717-dad9-4a06-972d-bb44acba468d-thumb.webp"}},"categories":[{"id":754,"category_id":1,"name":"Call of Duty: Warzone","slug":"call-of-duty-warzone","tags":["Shooter"],"description":null,"deleted_at":null,"viewers":2435,"category":{"id":1,"name":"Games","slug":"games","icon":"\ud83d\udd79\ufe0f"}}]},{"id":23772374,"slug":"52548782-labbin-n-chillin-happy-black-history-month-tab","channel_id":136914,"created_at":"2024-02-22 01:58:20","session_title":"Labbin n Chillin \u2618\ufe0f HAPPY BLACK HISTORY MONTH \u2618\ufe0f !tab","is_live":true,"risk_level_id":null,"start_time":"2024-02-22 01:58:17","source":null,"twitch_channel":null,"duration":0,"language":"English","is_mature":false,"viewer_count":98,"order":10,"thumbnail":{"srcset":"https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/1080.webp 1920w, https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/720.webp 1280w, https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/360.webp 480w, https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/160.webp 284w, https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/480.webp 640w","src":"https:\/\/images.kick.com\/video_thumbnails\/Blao45JPC2Vu\/A6Z5qDBWtJ0k\/720.webp"},"viewers":98,"channel":{"id":136914,"user_id":138506,"slug":"a1prospect","is_banned":false,"playback_url":"https:\/\/fa723fc1b171.us-west-2.playback.live-video.net\/api\/video\/v1\/us-west-2.196233775518.channel.Blao45JPC2Vu.m3u8","name_updated_at":"2023-03-15 21:32:53","vod_enabled":true,"subscription_enabled":true,"can_host":true,"user":{"id":138506,"username":"A1PROSPECT","agreed_to_terms":true,"email_verified_at":"2022-12-08T02:59:07.000000Z","bio":"Welcome to the family. Be yourself fuck validation \nAny Business Inquiries A1prospectttv@gmail.com","country":"","state":"","city":"","instagram":"A1pr0spect","twitter":"A1pr0spect","youtube":"A1PROSPECT","discord":"saucesquad","tiktok":"","facebook":"","profilepic":"https:\/\/files.kick.com\/images\/user\/138506\/profile_image\/conversion\/e4329ffa-59aa-46e1-93ab-8db3957bd887-thumb.webp"}},"categories":[{"id":5666,"category_id":1,"name":"Call of Duty: Modern Warfare III","slug":"call-of-duty-modern-warfare-iii","tags":["Shooter","Action","Warfare"],"description":null,"deleted_at":null,"viewers":566,"category":{"id":1,"name":"Games","slug":"games","icon":"\ud83d\udd79\ufe0f"}}]}],"first_page_url":"https:\/\/kick.com\/stream\/livestreams\/en?page=1","from":28,"next_page_url":"https:\/\/kick.com\/stream\/livestreams\/en?page=5","path":"https:\/\/kick.com\/stream\/livestreams\/en","per_page":9,"prev_page_url":"https:\/\/kick.com\/stream\/livestreams\/en?page=3","to":36}"""

from json import loads

data = loads(s,strict=False)
data["data"][0]
# Out:
# {'id': 23779615,
#  'slug': '81475268-deepak-x-hyub-last-day-in-jaisalmer',
#  'channel_id': 4431300,
#  'created_at': '2024-02-22 04:25:08',
#  'session_title': 'Deepak x Jay !tts !media !discord',
#  'is_live': True,
#  'risk_level_id': None,
#  'start_time': '2024-02-22 04:25:05',
#  'source': None,
#  'twitch_channel': None,
#  'duration': 0,
#  'language': 'English',
#  'is_mature': False,
#  'viewer_count': 914,
#  'order': 10,
#  'thumbnail': {'srcset': 'https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/1080.webp 1920w, https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/720.webp 1280w, https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/360.webp 480w, https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/160.webp 284w, https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/480.webp 640w',
#   'src': 'https://images.kick.com/video_thumbnails/MCrHDtiN4Bof/kL5U0P7DON1m/720.webp'},
#  'viewers': 914,
# ...

# %%
import pandas as pd

pd.DataFrame(data["data"],encoding="utf8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-1f06be6f26b0> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 pd.DataFrame(data["data"],encoding="utf8")
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'encoding'

# %% [markdown]
# Now, the same for [itch.io](itch.io). Again, only open the cells if you need help. How would you bring the data into Python?

# %%
# @title
import requests

url = "https://itch.io/games?page=33&format=json"
response = requests.get(url)

response.status_code
# Out:
# 200

# %%
# @title
games_data = response.json()
type(games_data)
# Out:
# dict

# %% [markdown]
# When I found the data, it was in a dictionary. Given a dictionary of game information, let's scrub through it. With dictionaries you look for their keys...

# %%
games_data.keys()
# Out:
# dict_keys(['num_items', 'content', 'page'])

# %%
games_data['num_items']
# Out:
# 36

# %% [markdown]
# It turns out that one of the keys has HTML content for the particular chunk of games (chunks appear as you scroll down the page). There's a hook to even iterate through the chunks programmatically.

# %%
from bs4 import BeautifulSoup

games_page = BeautifulSoup(games_data["content"])
print(games_page.prettify())
# Out:
# <html>
#  <body>
#   <div class="game_cell has_cover lazy_images" data-game_id="1514149" dir="auto">
#    <div class="game_thumb" style="background-color:#000000;">
#     <a class="thumb_link game_link" data-action="game_grid" data-label="game:1514149:thumb" href="https://ulfsire.itch.io/path-of-achra" tabindex="-1">
#      <img class="lazy_loaded" data-lazy_src="https://img.itch.zone/aW1nLzExNjg2NTcwLnBuZw==/315x250%23c/GXH%2FMA.png" height="250" width="315"/>
#     </a>
#     <div class="game_cell_tools">
#      <a class="action_btn add_to_collection_btn" data-register_action="add_to_collection" href="/g/ulfsire/path-of-achra/add-to-collection?source=browse">
#       <span class="icon icon-playlist_add">
#       </span>
#       Add to collection
#      </a>
#     </div>
#    </div>
#    <div class="game_cell_data">
#     <div class="game_title">
#      <a class="title game_link" data-action="game_grid" data-label="game:1514149:title" href="https://ulfsire.itch.io/path-of-achra">
# ...

# %% [markdown]
# Compare finding information in this HTML code versus in a dictionary. How are things different? What do you have to look to for to find the information you're after?
#
# Here we appeal to tag name and tag class. BeautifulSoup lets us search HTML for tags with certain attributes. It also can make use of a CSS selector directly. Here we just look for all the `<a>` anchor tags of class "title".

# %%
games = games_page.find_all("a","title")
len(games)
# Out:
# 36

# %%
games[10]
# Out:
# <a class="title game_link" data-action="game_grid" data-label="game:1534869:title" href="https://chedski.itch.io/sound-space-plus">Sound Space+</a>

# %%
type(games[0])

# %%
game = games[0]

print(game.prettify())
# Out:
# <a class="title game_link" data-action="game_grid" data-label="game:1514149:title" href="https://ulfsire.itch.io/path-of-achra">
#  Path of Achra
# </a>

# %%
game.get_text()
# Out:
# 'Path of Achra'

# %%
game["href"]
# Out:
# 'https://ulfsire.itch.io/path-of-achra'

# %% [markdown]
# And here we look for all the `<div>` tags with class "game_cell_data".

# %%
games = games_page.find_all("div","game_cell_data")
len(games)
# Out:
# 36

# %%
games[5]
# Out:
# <div class="game_cell_data"><div class="game_title"><a class="title game_link" data-action="game_grid" data-label="game:273630:title" href="https://insanus.itch.io/get-out">GET OUT of this Dungeon</a></div><div class="game_text" title="Locked in a dungeon. Find the gems to GET OUT. 8bit Metroidvania">Locked in a dungeon. Find the gems to GET OUT. 8bit Metroidvania</div><div class="game_author"><a data-action="game_grid" data-label="user:259464" href="https://insanus.itch.io">Insanus</a></div><div class="game_genre">Platformer</div><div class="game_platform"><span class="web_flag">Play in browser</span><span aria-hidden="true" class="icon icon-windows8" title="Download for Windows"></span> <span aria-hidden="true" class="icon icon-tux" title="Download for Linux"></span> <span aria-hidden="true" class="icon icon-apple" title="Download for macOS"></span> </div></div>

# %%
game = games[5]
print(game.prettify())
# Out:
# <div class="game_cell_data">
#  <div class="game_title">
#   <a class="title game_link" data-action="game_grid" data-label="game:273630:title" href="https://insanus.itch.io/get-out">
#    GET OUT of this Dungeon
#   </a>
#  </div>
#  <div class="game_text" title="Locked in a dungeon. Find the gems to GET OUT. 8bit Metroidvania">
#   Locked in a dungeon. Find the gems to GET OUT. 8bit Metroidvania
#  </div>
#  <div class="game_author">
#   <a data-action="game_grid" data-label="user:259464" href="https://insanus.itch.io">
#    Insanus
#   </a>
#  </div>
#  <div class="game_genre">
#   Platformer
#  </div>
#  <div class="game_platform">
#   <span class="web_flag">
#    Play in browser
#   </span>
#   <span aria-hidden="true" class="icon icon-windows8" title="Download for Windows">
#   </span>
#   <span aria-hidden="true" class="icon icon-tux" title="Download for Linux">
#   </span>
#   <span aria-hidden="true" class="icon icon-apple" title="Download for macOS">
#   </span>
#  </div>
# ...

# %% [markdown]
# BeautifulSoup really is beautiful. You can take one of the games we've found and dig into it. It's just another tag, after all.

# %%
game.find("div","game_genre")
# Out:
# <div class="game_genre">Platformer</div>

# %%
game.find("div","game_genre").get_text()
# Out:
# 'Platformer'

# %% [markdown]
# And here we iterate through the games, makings lists of game titles and game authors, eventually creating a DataFrame. We could imagine iterating this and getting all the games.

# %%
who = []
what = []

for game in games:
  what.append(game.find("a","title").get_text())
  who.append(game.find("div","game_author").get_text())

import pandas as pd

game_df = pd.DataFrame({"author":who,"title":what})
game_df
# Out:
#                   author                                      title
# 0                Ulfsire                              Path of Achra
# 1              KenForest                            Liminal Gallery
# 2          PerroAutonomo                                BIOHAZARD 2
# 3     Four Quarters team            LooPatHerO (alpha of Loop Hero)
# 4               Devikomi                          Crystal the Witch
# 5                Insanus                    GET OUT of this Dungeon
# 6               Zeekerss                                  It Steals
# 7         Ibrahim Oezhan                                  The Pizza
# 8              LarkyLabs                               Glam Pursuit
# 9          AdamDubiGames                       Adam - Lost Memories
# 10               Chedski                               Sound Space+
# 11               Al Heck                        Paranormal Entities
# 12             Lsgamedev                              Ouija Rumours
# ...

# %% [markdown]
# Close out this notebook by looking at the ACS comments and see if there is another way besides scraping to get the data.
